# %% [markdown]
# # Evaluating Impact of Stirring of Espresso on Total Dissolved Solids (TDS)
#
# There have been several studies of TDS measurement in the context of precision of espresso devices. These studies have adopted procedures for stirring the espresso upfront using a spoon, specifying a number of stirs. The question this study looks to evaluate is the impact stirring methodology has on measuring TDS in espresso.
#
# ## Equipment
#
# * Coffee: [Candlestick](https://candlestickcoffee.com/) Kenyan.
#   * Selected based on Jonathan Gagné's [post](https://coffeeadastra.com/2020/09/05/the-effects-of-varieties-origin-and-processing/) that indicates Kenyan coffees to have higher extraction yields, though do not have a reason to believe this should have any impact.
# * TDS Device: [Atago Coffee refractometer](https://www.atago.net/product/?l=en&f=products-pal-top.php#CGD50756)
# * Scales:
#     * [Acaia Lunar](https://acaia.co/products/lunar) 0.1g readability. Used for measuring espresso weight during pull
#     * [Acaia Pearl](https://acaia.co/products/pearl) 0.1g readability. Used to weigh out beans
#     * [Fuzion Pocket Scale](https://www.amazon.com/Back-Lit-Function-Multifunction-Medicine-Collections/dp/B07L8ZVVRM/) 0.01g readability. Used to measure liquid samples to be evaporated.
# * Espresso Machine: [Linea Mini](https://home.lamarzoccousa.com/linea-mini/)
# * Grinder: [Kafatek Flat: SSP Red](https://www.kafatek.com/index.php/monolith-titan-flat-burr-espresso-grinder/)
# * Tamper: [Decent Tamper V3](https://decentespresso.com/tamper)
# * 'Distribution' Tool: [Pullman Chisel](https://pullman.coffee/news/147-chisel-redistribution-tool)
# * Basket: [VST 20g Basket](https://store.vstapps.com/products/vst-precision-filter-baskets)
# * Water: Distill 1 Gallon and with one packet of [Third Wave Water Espresso Profile](https://thirdwavewater.com/products/1-gallon-espresso-profile?variant=32477449289774) added
#
# ## Espresso Methodology
#
# ### Initial Preparation
#
# 1. Calibrate Acaia Lunar/Pearl using method described [here](https://help.acaia.co/hc/en-us/articles/360035746811-How-to-calibrate-your-Lunar-Pearl-Pearl-Model-S-Pearl-2021-or-Pyxis-scale)
#
# ### Pulling Shot
#
# [//]: # (Record ambient temperature?)
# 1. Weigh out 18.5g of coffee beans using the Acaia Pearl
# 1. **How much can this vary weight???** Spray Beans once with small spray bottle that came with grinder
# 1. Grind beans into Portafilter, pouring beans in all at once
# 1. Remove excess grounds to achieve 18.0g within basket
# 1. Tap portafilter on workspace twice, flatten bed using 'distribution' tool, then tamp
# 1. Place portafilter in machine, place cup on scale, tare.
# 1. Engage machine and scale timer at same time
# 1. Disengage machine when weight in cup reaches 36.0g
# 1. Record final weight, pull time of shot as well as date and timetime
# 1. Proceed to [measure TDS](#Measuring-TDS) using randomly selected method
#
# ## Measuring TDS
#
# There are three methods with which TDS will be measured for this experiment, they are as follows:
#
# 1. Stir espresso with spoon, sample, cool, measure without filtering
# 2. Stir espresso with stir plate, sample, cool, measure without filtering
# 3. Weigh dissolved solids as described [here][4]
#
# The third method will be performed for every shot, which is intended as more accurate measure of the true TDS. while the sampling order of using a spoon to stir vs a stir plate will be decided up front using a Random Number Generator (RNG) to avoid measurement errors caused by sampling sequentially (getting tired, getting sloppy, etc).
#
# ### Syringe Reuse
#
# Syringes are made up a significant amount of plastic, and perform this experiment to the standards found in a lab would require a lot of syringes used once then thrown out. This wasteful for a measurement that has low impact (IE good vs great coffee compared to say telling if a molecule is a drug or not). With that in mind syringes will be reused in a way that attempts to produce defensible values while avoiding too much waste.
#
# The syringes that collect the samples from the stirred coffee will be reused for the unfiltered TDS testing as well as collecting the sample for measuring the 'true' dissolved solids via evaporation[[4][4]].
#
# There is an additional syringe used to tare the refractometer with distilled, which will be reused through out.
#
# ### Initial Preparation
#
# 1. Calibrate Fuzion Pocket Refractometer with provided 50g weight, instructions provided inside of case.
#
# ### Collect Samples
#
# 1. Perform stirring method selected for shot [Spoon](#Stirring-With-a-Spoon) or [Stir Plate](#Stirring-With-Stir-Plate)
# 1. [Extract](#Extracting-Sample-Procedure) samples and place into container attempting to get as close to 10g as possible. Weigh record total weight of sample, label and set aside.
# 1. Use 3ml syringe to [extract](#Extracting-Sample-Procedure) two 3ml samples, from below crema, place into metal 'shot glass' to [cool](#Cooling-Procedure).
# 1. Wait 5 minutes for cooling
# 1. For three separate 1.0ml samples, perform the following steps
#     1. Clean refractometer sensor, tare using distilled water
#     1. Draw up 1.0ml of liquid
#     1. Dipose of first 4 drops
#     1. Fill refractometer sensor area
#     1. Collect TDS and Temperature (from refractometer) every 30 seconds until TDS converges three times in a row or 10 times, whichever comes first.
# 1. Place set aside sample with ~10g into oven at 255F (123.89C)
# 1. Once sample is dry, compute TDS, record. Done afterwards
#
#
# ###  Stirring With a Spoon
#
# 1. Stir shot with a small spoon ten times clockwise and ten times counterclockwise
#
# ### Stirring With Stir Plate
#
# 1. Add clean stir rod
# 1. Turn on stir plate to lowest speed that creates clean vortex without splatter
# 1. Wait 10 seconds
# 1. Turn off stir plate, wait for liquid to stop spinning.
#
# ## Cooling Procedure
#
# 1. Use metal shot glasses to cool samples
# 1. Place samples on laptop cooling pad, turn on full
#
#
# ## Extracting Sample Procedure
#
# When extracting a sample using a syringe, place the syringe underneath the crema and draw into syringe and push back into the cup three times. Keep the fourth draw.[[2][2]]
#
#
# ## Disclosures
#
# None of the equipment used in this experiment was provided to me and represents a setup similar to what I commonly use.
#
#
# ## References
#
# * \[1\] [Measuring Total Dissolved Solids: A Refractometer Comparison - Socratic Coffee][1]
# * \[2\] [Centrifuging Espresso - A Waste of Coffee][2]
# * \[3\] [Measuring Coffee Concentration with a 0.01% Precision - Coffee Ad Astra][3]
# * \[4\] [Measuring TDS without refractometer - NP Coffee Science][4]
# * \[5\] [Stop Swirling Your Espresso - James Hoffman][5]
#
# [1]: <https://socraticcoffee.com/2015/07/measuring-total-dissolved-solids-a-refractometer-comparison-part-iii-espresso-filters/e> "Measuring Total Dissolved Solids: A Refractometer Comparison - Socratic Coffee"
# [2]: <https://awasteof.coffee/2019/02/12/centrifuging-espresso/> "Centrifuging Espresso - A Waste of Coffee"
# [3]: <https://coffeeadastra.com/2019/09/21/measuring-coffee-concentration-with-a-0-01-precision/> "Measuring Coffee Concentration with a 0.01% Precision - Coffee Ad Astra"
# [4]: <https://www.npcoffeescience.com/post/measuring-tds-without-refractometer> "Measuring TDS without refractometer - NP Coffee Science"
# [5]: <https://www.youtube.com/watch?v=iI09bbH22vQ> "Stop Swirling Your Espresso - James Hoffman"

# %%
import os
import math

from collections import defaultdict
from tempfile import NamedTemporaryFile

import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import r2_score, mean_absolute_error
from scipy.stats import kendalltau, pearsonr

from IPython.core.display import display

# %% [markdown]
# # Generate ordering of samples
#
# * **1** indicates to stir sample using a spoon
# * **2** indicates to stir sample using stir plate

# %%
# Seed the RNG to ensure consistent results across notebook runs
np.random.seed(814)

samples = np.asarray([1, 2])
number_of_pairs = 5 # Run an equal number of pairs
count = 0
for _ in range(number_of_pairs):
    np.random.shuffle(samples)
    for val in samples: # only take two, as we want pairs
        count += 1    

        method = "Spoon"
        if val == 2:
            method = "Stir Plate"
        print(f"Stir sample {count} with {method}")
# Out:
# Stir sample 1 with Spoon
# Stir sample 2 with Stir Plate
# Stir sample 3 with Spoon
# Stir sample 4 with Stir Plate
# Stir sample 5 with Stir Plate
# Stir sample 6 with Spoon
# Stir sample 7 with Stir Plate
# Stir sample 8 with Spoon
# Stir sample 9 with Spoon
# Stir sample 10 with Stir Plate

# %%
DATA_DOWNLOAD_URL = "https://docs.google.com/spreadsheets/d/1dDfuIq74pjELNtfb_0sdiNnG3qFKrfqC2sax7ewrWYg/export?format=csv&gid=1739174083"
plt.rcParams["figure.dpi"] = 150

# %%
# Download CSV, won't work on windozes
with NamedTemporaryFile(suffix=".csv") as temp:
    with open(temp.name, "wb") as ofs:
        resp = requests.get(DATA_DOWNLOAD_URL, stream=True)
        for chunk in resp.iter_content():
            ofs.write(chunk)
    df = pd.read_csv(temp.name)
# Clean up the CSV file.
for char in [' ', '(', ')', "%", "/", "\\", '"']:
    df.columns = df.columns.str.strip().str.lower().str.replace(char, '')
df = df[df["grinder"].astype(bool)][df["grindersetting"].astype(bool)]
# Only look at data with TDS values and ratings
df = df.assign(extraction_yield = (df.tds * df.output) / df.coffeegrams)
df.date = pd.to_datetime(df.date, infer_datetime_format=True, utc=True)
df.roastdate = pd.to_datetime(df.roastdate, infer_datetime_format=True, utc=True)
df = df.assign(days_off_roast = df.date - df.roastdate)

evaporated_df = df[~df["containerweight+driedsolids"].isna()]
evaporated_df = evaporated_df.assign(
    tds=np.abs(
        (evaporated_df["containerweight+driedsolids"] - evaporated_df["containerweight"]) / evaporated_df.liquidweight * 100
    )
)
evaporated_df = evaporated_df.assign(extraction_yield = (evaporated_df.tds * evaporated_df.output) / evaporated_df.coffeegrams)
df.drop(df[df.tds.isna()].index, inplace=True)

# %% [markdown]
# ## Hypothesis #1: Stir Method
#
#
# The variance in the TDS values would be lower for the stir plate due to a more even mixing of the sample, resulting in a more precise TDS result.

# %%
columns = []
times = []
coloring = []
samples = []
fig = plt.Figure()
axe = fig.add_axes([0, 0, 1, 1])
run_colors = ["blue", "red", "green"]
for name, subdf in df.groupby(["procedure", "sample"]):
    subdf.drop(subdf[subdf.tds.isna()].index, inplace=True)
    columns.append(f"{name[1]}: {name[0]}")
    sub_colors = []
    samples.append(name[1])
    for run in subdf.run.values:
        sub_colors.append(run_colors[run-1])
    coloring.append(sub_colors)
    times.append(subdf.tds.values)
axe.boxplot(times, labels=columns)
i = 0
uni_range = 0.05
for column, vals, colors, sample in zip(columns, times, coloring, samples):
    center = i+1
    biff = axe.scatter(np.random.uniform(center - uni_range, center + uni_range, len(vals)), vals, alpha=0.3, c=colors)
    true_val = evaporated_df[evaporated_df["sample"] == sample]
    if len(true_val):
        true_lines = axe.plot([center-0.2, center+0.2], [true_val.tds.values[0], true_val.tds.values[0]], color="black", linestyle="--", label="Total Solids")
    avg_lines = axe.plot([center-0.2, center+0.2], [np.mean(vals), np.mean(vals)], color="blue", linestyle="--", label="Average")
    i += 1
axe.legend(handles=[true_lines[0], avg_lines[0]], bbox_to_anchor=(0, -0.4), loc='lower left')
axe.set_xticklabels(columns, rotation=35, ha='center')
axe.set_title("TDS Measurement Distributions")
axe.set_xlabel("Sample and Procedure")
axe.set_ylabel("TDS (%)")
handles, labels = axe.get_legend_handles_labels()
handle_list, label_list = [], []
for handle, label in zip(handles, labels):
    if label not in label_list:
        handle_list.append(handle)
        label_list.append(label)
axe.legend(handle_list, label_list)
display(fig)

# %%
print("TDS")
print("="*3)
for name, subdf in df.groupby(["sample", "procedure"]):
    subdf.drop(subdf[subdf.tds.isna()].index, inplace=True)
    true_val = evaporated_df[evaporated_df["sample"] == name[0]]
    if len(true_val) == 0:
        continue
    print(
        "Stir Method",
        name[1],
        "Sample",
        name[0],
        "Evaporated Total Solids",
        "{:<5}".format(np.round(true_val.tds.values[0], 2)),
        "Mean",
        "{:6}".format(np.round(subdf.tds.mean(), 3)),
        "Variance",
        "{:<5}".format(np.round(subdf.tds.var(), 3)),
        "Max Deviation",
        np.round(subdf.tds.mad(), 3),
    )
print()
print("Extraction Yield")
print("="*16)
for name, subdf in df.groupby(["sample", "procedure"]):
    subdf.drop(subdf[subdf.tds.isna()].index, inplace=True)
    true_val = evaporated_df[evaporated_df["sample"] == name[0]]
    if len(true_val) == 0:
        continue
    print(
        "Stir Method",
        name[1],
        "Sample",
        name[0],
        "Evaporated EY",
        "{:<5}".format(np.round(true_val.extraction_yield.values[0], 2)),
        "Mean",
        "{:<6}".format(np.round(subdf.extraction_yield.mean(), 3)),
        "Variance",
        "{:<5}".format(np.round(subdf.extraction_yield.var(), 3)),
        "Max Deviation",
        np.round(subdf.extraction_yield.mad(), 3),
    )
# Out:
# TDS
# ===
# Stir Method spoon stir Sample 1 Evaporated Total Solids 10.26 Mean  9.636 Variance 0.019 Max Deviation 0.11
# Stir Method stir plate Sample 2 Evaporated Total Solids 11.4  Mean 10.835 Variance 0.004 Max Deviation 0.052
# Stir Method spoon stir Sample 3 Evaporated Total Solids 11.0  Mean 10.844 Variance 0.056 Max Deviation 0.202
# Stir Method stir plate Sample 4 Evaporated Total Solids 11.4  Mean 10.838 Variance 0.012 Max Deviation 0.094
# Stir Method stir plate Sample 5 Evaporated Total Solids 10.8  Mean 10.202 Variance 0.058 Max Deviation 0.202
# Stir Method spoon stir Sample 6 Evaporated Total Solids 11.1  Mean 10.328 Variance 0.03  Max Deviation 0.158
# Stir Method stir plate Sample 7 Evaporated Total Solids 11.5  Mean 10.303 Variance 0.018 Max Deviation 0.114
# Stir Method spoon stir Sample 8 Evaporated Total Solids 11.0  Mean 10.218 Variance 0.087 Max Deviation 0.25
#
# Extraction Yield
# ================
# Stir Method spoon stir Sample 1 Evaporated EY 21.6  Mean 20.29  Variance 0.085 Max Deviation 0.232
# Stir Method stir plate Sample 2 Evaporated EY 23.88 Mean 22.694 Variance 0.016 Max Deviation 0.109
# Stir Method spoon stir Sample 3 Evaporated EY 22.73 Mean 22.411 Variance 0.24  Max Deviation 0.418
# Stir Method stir plate Sample 4 Evaporated EY 23.75 Mean 22.578 Variance 0.053 Max Deviation 0.196
# Stir Method stir plate Sample 5 Evaporated EY 22.8  Mean 21.538 Variance 0.259 Max Deviation 0.426
# Stir Method spoon stir Sample 6 Evaporated EY 23.5  Mean 21.86  Variance 0.135 Max Deviation 0.333
# Stir Method stir plate Sample 7 Evaporated EY 24.15 Mean 21.636 Variance 0.08  Max Deviation 0.24
# Stir Method spoon stir Sample 8 Evaporated EY 23.28 Mean 21.627 Variance 0.39  Max Deviation 0.528

# %% [markdown]
# ## Hypothesis #1: Conclusion
#
# With only a sample size of 6, the results are inconclusive. While two of the samples for the stir plate are lower than the spoon stir methods, the other sample has the greatest variance.
#
# ### Follow Up
#
# * Collect more samples
# * Compare to the 'accurate' method

# %% [markdown]
# ## Hypothesis #2: Unfiltered TDS provides ranks ordering
#
# While unfiltered measurements of espresso does not provide the most precise reading [[1](https://socraticcoffee.com/2015/07/measuring-total-dissolved-solids-a-refractometer-comparison-part-iii-espresso-filters/)], rank ordering is what matters for dialing in coffee. Despite the lack of precise, does measuring the unfiltered espresso produce a meaningful rank ordering?

# %%
for run in df.run.unique():
    taus = {}
    all_x = []
    all_y = []
    for name, subdf in df.groupby(["procedure"]):
        subdf = subdf[subdf.run == run]
        xs = []
        ys = []
        # Only look at the first run
        for _, otherdf in subdf.groupby(["sample"]):
            otherdf = otherdf[otherdf.run == run]
            true_df = evaporated_df[evaporated_df["sample"] == otherdf["sample"].values[0]]
            if len(true_df):
                true_val = true_df.tds.values[0]
                xs.extend([true_val]*len(otherdf.tds.values))
                ys.extend(otherdf.tds.values)
        taus[name] = kendalltau(xs, ys)
        plt.scatter(xs, ys, marker="x", label=name)
        all_x.extend(xs)
        all_y.extend(ys)
    plt.xlabel("Total Evaporated Solids (%)")
    plt.ylabel("TDS (%)")
    plt.legend(labels=["spoon stir", "stir plate"])
    model_stats = {
        "Spoon τ = {:.2f}, p = {:.2f}": taus["spoon stir"],
        "Stir Plate τ = {:.2f}, p = {:.2f}": taus["stir plate"],
        "τ = {:.2f}, p = {:.2f}": kendalltau(all_x, all_y),
        "$R^2$: {:.2f}": [r2_score(all_x, all_y)],
        "pearson $r^2$: {:.2f}, p = {:.2f}": [pearsonr(all_x, all_y)[0]**2, pearsonr(all_x, all_y)[1]],
        "mae: {:.2f}": [mean_absolute_error(all_x, all_y)],
    }
    for i, (name, stat) in enumerate(model_stats.items()):
        plt.annotate(
            name.format(*stat),
            (0.55, -0.2 - 0.05 * i),
            xycoords="axes fraction"
        )
    plt.title(f"Run {run} Rank Ordering")
    plt.show()

# %% [markdown]
# ## Hypothesis #2: Conclusion
#
# There is a rank ordering to be found within the data, across all 6 samples. However the sample size is small, particularly with the two methods. There is also a lack of comparison to the conventional rank ordering tool, filtered espresso.
#
# ### Follow Up
#
# * Collect data on filtered samples
# * Collect more data in general

# %% [markdown]
# ## Hypothesis #3: Samples Evaporate Over time
#
# While measuring one sample, the following sample will have a higher TDS due to evaporation. Implies that samples collected and tested sooner might be more 'accurate' for computing Extraction Yield.

# %%
colors = ["blue", "red", "green", "pink", "purple", "gray", "black", "orange"]
stride = len(colors) // len(df["sample"].unique())
taus = []
for name, subdf in df.groupby(["procedure", "sample"]):
    subdf.drop(subdf[subdf.tds.isna()].index, inplace=True)
    plt.scatter(
        subdf.run.values,
        subdf.tds.values,
        color=colors[name[1]-1],
        label=f"Method {name[0]}, Sample {name[1]}",
        marker="x"
    )
    taus.append(kendalltau(subdf.run.values, subdf.tds.values))
    poly_fit = np.poly1d(np.polyfit(subdf.run.values, subdf.tds.values, 1))
    plt.plot(
        subdf["run"].unique(),
        poly_fit(subdf["run"].unique()),
        linestyle="--",
        color=colors[name[1]-1]
    )
plt.title("Impact of Evaporation on TDS")
plt.ylabel("TDS (%)")
plt.xlabel("Run")
plt.xticks(np.arange(1, 4, 1.0))
plt.legend(bbox_to_anchor=(0, -.72), loc='lower left')
plt.annotate(
    "Average Kendall Tau = {:.2f}".format(np.mean([x[0] for x in taus])),
    (0.55, 0.01),
    xycoords="axes fraction",
)
plt.show()

# %% [markdown]
# ## Hypothesis #3: Conclusion
#
# There is definitely a trend to indicate that as samples are left to cool for longer they evaporate. This results
# in an increased TDS measurement. Likely indicates that running multiple samples in this fashion is not useful for comparing variance, without some means to counteract the evaporation.
#
# ### Follow Up
#
# * Could the use of a (tiny) copper wort chiller reduce cooling time and thus evaporation?

# %% [markdown]
# ## Investigation
#
# How well can we perform if we assume certain levels of error within our experimental data? The Atago reports precision that is within 0.15, if we [model this error](http://practicalcheminformatics.blogspot.com/2019/07/how-good-could-should-my-models-be.html) how well could we expect to perform?
#
# Note that the Atago [claims](https://www.atago.net/ru/pdf/tanpin-catalog/pal-coffee_a5_en.pdf) error can be as high as 0.5 for unfiltered espresso.

# %%
x = np.linspace(5.0, 13.0, 200)
y = np.copy(x)
fig, axs = plt.subplots(2,2)
err_folds = [1, 3, 5, 10]
precision = 0.15
axs = axs.reshape(-1)
for i, err in enumerate(err_folds):
    err_add = np.random.normal(0, precision*err, size=y.shape)
    axs[i].scatter(x, y+err_add, s=2)
    axs[i].set_title(f"Error Fold {err}")
    axs[i].set_xlabel("TDS (%)")
    if i % 2 == 0:
        axs[i].set_ylabel("TDS + Error (%)")
fig.suptitle("Modeling Error in Precision")
fig.tight_layout()
plt.show()

# %%
for refract, precision in [("Atago", 0.15), ("VST V3", 0.01)]:
    cor_list = []
    for fold in err_folds:
        for _ in range(1000):
            error = np.random.normal(0, fold*precision, size=y.shape)
            cor_list.append([r2_score(x, y+error), f"Error: {fold*precision:.2f}\nFold {fold}"])
    error_df = pd.DataFrame(cor_list,columns=["r2","fold_error"])
    axes = error_df.boxplot("r2", "fold_error")
    axes.set_xlabel("Fold")
    axes.set_ylabel("$R^2$")
    axes.set_title("")
    axes.tick_params(labelrotation=50)
    fig = axes.get_figure()
    fig.suptitle(f"{refract} - Base Precision {precision}")

# %% [markdown]
# ## Investigation Summary
#
# As one would expect, the VST III refractormeter behaves much better even if the error is increased, which makes sense it is 15x more precise. On the other hand, even with an error 5x greater than what is suggested by Atago, there is still a correlation of R^2 ~= 0.9. That 5x point of 0.5 error is where unfiltered espresso would lie, which suggests that assuming no other factors that the Atago should still be capable of reliable rank ordering.
#
# ### Follow Up
#
# * Is r^2 the right metric to evaluate, perhaps pearsonr or kendall tau?
# * Determine how to relate this back to the experimental data.
